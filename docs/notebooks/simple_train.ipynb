# %%
# %run load_data.py

# %%
x_train, y_train, x_test, y_test = load_data('mnist')
# Out:
# /home/zhampel/py-venv/python3/lib/python3.5/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# x_train shape: (60000, 28, 28, 1)
# 60000 train samples
# 10000 test samples

# %%
print(x_train.shape)
print(y_train.shape)
num_classes = y_train.shape[1]
print("Number of Classes: ", num_classes)
# Out:
# (60000, 28, 28, 1)
# (60000, 10)
# Number of Classes:  10

# %%
data = [num_classes, x_train, y_train, x_test, y_test]

# %%
# %run model.py
history, model = model(data)
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/10
# 60000/60000 [==============================] - 6s 99us/step - loss: 0.1528 - acc: 0.9532 - val_loss: 0.0465 - val_acc: 0.9851
# Epoch 2/10
# 60000/60000 [==============================] - 5s 80us/step - loss: 0.0400 - acc: 0.9876 - val_loss: 0.0345 - val_acc: 0.9891
# Epoch 3/10
# 60000/60000 [==============================] - 5s 85us/step - loss: 0.0275 - acc: 0.9913 - val_loss: 0.0323 - val_acc: 0.9890
# Epoch 4/10
# 60000/60000 [==============================] - 5s 87us/step - loss: 0.0198 - acc: 0.9935 - val_loss: 0.0244 - val_acc: 0.9921
# Epoch 5/10
# 60000/60000 [==============================] - 5s 78us/step - loss: 0.0150 - acc: 0.9952 - val_loss: 0.0249 - val_acc: 0.9928
# Epoch 6/10
# 60000/60000 [==============================] - 5s 79us/step - loss: 0.0128 - acc: 0.9956 - val_loss: 0.0288 - val_acc: 0.9915
# Epoch 7/10
# ...

# %%
# %run plots.py

# %%
plot_accuracy(history)
# Out:
# /home/zhampel/py-venv/python3/lib/python3.5/site-packages/matplotlib/figure.py:2267: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   warnings.warn("This figure includes Axes that are not compatible "

# %%
plot_loss(history)
# Out:
# /home/zhampel/py-venv/python3/lib/python3.5/site-packages/matplotlib/figure.py:2267: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   warnings.warn("This figure includes Axes that are not compatible "

# %%
x_train_r, y_train_r, x_test_r, y_test_r = load_data('mnist_rot')
score = model.evaluate(x_test, y_test, verbose=0)
score_rot = model.evaluate(x_test_r, y_test_r, verbose=0)
print("Upright score: ", score)
print("Rotated score: ", score_rot)
# Out:
# (60000, 28, 28)
# x_train shape: (60000, 28, 28, 1)
# 60000 train samples
# 10000 test samples
# Upright score:  [0.03557698416387843, 0.9913]
# Rotated score:  [9.796362705993653, 0.1861]

# %%
# Check on rotated by 90 samples
# %run load_data.py

# %%
x_train, y_train, x_test, y_test = load_data('mnist_rot')
num_classes = y_train.shape[1]
data_rot = [num_classes, x_train, y_train, x_test, y_test]

# %%
print(type(x_train))

# %%
# %run model.py
history, model = model(data_rot)

# %%
# %run plots.py

# %%
plot_accuracy(history)

# %%
plot_loss(history)
